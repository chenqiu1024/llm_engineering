# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# constants

# MODEL_GPT = 'gpt-4o-mini'
MODEL_GPT = 'gpt-4o-2024-05-13'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Define system and user prompts
system_prompt = """You are a technical programming assistant. Your task is to explain code snippets and programming concepts in a clear, concise, and educational manner. Focus on:
1. What the code does
2. Why it's written that way
3. Any important concepts or patterns used
4. Potential use cases
Format your response in markdown for better readability."""

user_prompt = f"""Please analyze and explain the following code:

{question}"""

# %%
# Get gpt-4o-mini to answer, with streaming
###
message = [
    {'role':'system', 'content':system_prompt},
    {'role':'user', 'content':user_prompt}
]

# %%
response = openai.chat.completions.create(
    model=MODEL_GPT,
    messages=message,
    stream=True
)

print("\nGPT-4 Response:")
print("-" * 50)
for chunk in response:
    if chunk.choices[0].delta.content:
        print(chunk.choices[0].delta.content, end='', flush=True)
print("\n" + "-" * 50)
# Out:
# GPT-4 Response:
# --------------------------------------------------
# Sure! Let me break down the code snippet for you:
#
# ```python
# yield from {book.get("author") for book in books if book.get("author")}
# ```
#
# ### 1. What the Code Does
#
# - **Input:** This code works on a sequence of dictionaries (`books`), each of which represents a book.
# - **Output:** It generates all unique authors present in the `books` list.
#
# ### 2. Why It's Written That Way
#
# The code uses a set comprehension and a `yield from` statement to:
#
# - Extract the value associated with the key `"author"` from each dictionary in the `books` list.
# - Ensure that only dictionaries containing an `"author"` key (with a non-null value) are considered.
# - Collect these values into a set to eliminate duplicates.
# - Yield each unique author from the set.
#
# ### 3. Important Concepts or Patterns Used
#
# #### **Set Comprehension:**
# - **Syntax:** `{expression for item in iterable if condition}`
# - In this code, it creates a set of authors.
# - **Explanation:** `{book.get("author") for book in books if book.get("author")}`
#   - `book.get("author")`: Fetches the value of the `"author"` key from each dictionary.
#   - `for book in books`: Iterates through each dictionary in the `books` list.
#   - `if book.get("author")`: Ensures that only dictionaries with a non-null `"author"` are included.
#
# #### **`yield from` Statement:**
# - **Purpose:** Delegates part of a generator's operations to another iterator.
# - **Explanation:** `yield from { ... }`
#   - This statement yields all elements from the set one by one.
#   - Makes the enclosing function a generator.
#
# ### 4. Potential Use Cases
#
# - **Streamlining Data Extraction:** When dealing with large lists of dictionaries, this approach efficiently extracts and yields unique authors without duplication.
# - **Lazy Evaluation:** Using `yield from` provides a memory-efficient way to iterate over results on demand, suitable for large datasets.
# - **Data Cleaning and Transformation:** Ideal in scenarios where you need to clean data by removing duplicates while processing items.
#
# ### Example
#
# Here's a practical example to illustrate the usage:
#
# ```python
# books = [
#     {"title": "Book 1", "author": "Author A"},
#     {"title": "Book 2", "author": "Author B"},
#     {"title": "Book 3", "author": "Author A"},
#     {"title": "Book 4", "author": None},
#     {"title": "Book 5"}
# ]
#
# def unique_authors(books):
#     yield from {book.get("author") for book in books if book.get("author")}
#
# # Using the generator to print unique authors
# for author in unique_authors(books):
#     print(author)
# ```
#
# In this example:
#
# - The function `unique_authors` processes the list of books.
# - It uses the set comprehension to gather unique authors.
# - The `yield from` statement yields each unique author one by one.
# - Finally, a loop prints out each unique author (`Author A` and `Author B`). Note that `None` and books without authors are excluded.
# --------------------------------------------------
